# %% [markdown]
# 2408658

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Input, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

df = pd.read_csv("/content/mnist_dataset.csv")

y = df.iloc[:, 0].values
x = df.iloc[:, 1:].values.astype("float32") / 255.0

x = x.reshape(-1, 28, 28, 1)

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)

model = Sequential([
    Input(shape=(28, 28, 1)),
    Flatten(),
    Dense(64, activation='sigmoid'),
    Dense(128, activation='sigmoid'),
    Dense(256, activation='sigmoid'),
    Dense(10, activation='softmax')
])

model.summary()

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

checkpoint = ModelCheckpoint(
    "best_fcn_model.h5",
    monitor="val_accuracy",
    save_best_only=True,
    mode="max",
    verbose=1
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True,
    verbose=1
)

history = model.fit(
    x_train,
    y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.2,
    callbacks=[checkpoint, early_stop],
    verbose=1
)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=1)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)

model.save("devnagari_fcn_model.h5")

loaded_model = load_model("devnagari_fcn_model.h5")

loaded_loss, loaded_acc = loaded_model.evaluate(x_test, y_test, verbose=1)
print("Loaded Model Test Loss:", loaded_loss)
print("Loaded Model Test Accuracy:", loaded_acc)

predictions = loaded_model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=1)

print(predicted_labels[:10])
print(y_test[:10])

plt.figure(figsize=(12, 8))
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title(f"P:{predicted_labels[i]} | T:{y_test[i]}")
    plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# (48000, 28, 28, 1)
# (48000,)
# (12000, 28, 28, 1)
# (12000,)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 299/300 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3904 - loss: 1.8191
# Epoch 1: val_accuracy improved from None to 0.88021, saving model to best_fcn_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to best_fcn_model.h5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6253 - loss: 1.2201 - val_accuracy: 0.8802 - val_loss: 0.4595
# Epoch 2/20
# 296/300 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8870 - loss: 0.4044
# Epoch 2: val_accuracy improved from 0.88021 to 0.91562, saving model to best_fcn_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: finished saving model to best_fcn_model.h5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9004 - loss: 0.3511 - val_accuracy: 0.9156 - val_loss: 0.2971
# Epoch 3/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9238 - loss: 0.2657
# Epoch 3: val_accuracy improved from 0.91562 to 0.93323, saving model to best_fcn_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: finished saving model to best_fcn_model.h5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9274 - loss: 0.2536 - val_accuracy: 0.9332 - val_loss: 0.2305
# Epoch 4/20
# 295/300 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9385 - loss: 0.2172
# Epoch 4: val_accuracy improved from 0.93323 to 0.94083, saving model to best_fcn_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4: finished saving model to best_fcn_model.h5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9414 - loss: 0.2045 - val_accuracy: 0.9408 - val_loss: 0.2023
# Epoch 5/20
# 295/300 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9511 - loss: 0.1703
# Epoch 5: val_accuracy improved from 0.94083 to 0.94698, saving model to best_fcn_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 5: finished saving model to best_fcn_model.h5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9506 - loss: 0.1698 - val_accuracy: 0.9470 - val_loss: 0.1774
# Epoch 6/20
# 289/300 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9587 - loss: 0.1433
# Epoch 6: val_accuracy improved from 0.94698 to 0.95365, saving model to best_fcn_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6: finished saving model to best_fcn_model.h5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9581 - loss: 0.1441 - val_accuracy: 0.9536 - val_loss: 0.1596
# Epoch 7/20
# 293/300 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9653 - loss: 0.1215
# Epoch 7: val_accuracy improved from 0.95365 to 0.95417, saving model to best_fcn_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: finished saving model to best_fcn_model.h5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9639 - loss: 0.1245 - val_accuracy: 0.9542 - val_loss: 0.1535
# Epoch 8/20
# 295/300 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9679 - loss: 0.1102
# Epoch 8: val_accuracy improved from 0.95417 to 0.95823, saving model to best_fcn_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 8: finished saving model to best_fcn_model.h5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9684 - loss: 0.1091 - val_accuracy: 0.9582 - val_loss: 0.1398
# Epoch 9/20
# 296/300 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9700 - loss: 0.1025
# Epoch 9: val_accuracy improved from 0.95823 to 0.96177, saving model to best_fcn_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 9: finished saving model to best_fcn_model.h5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9721 - loss: 0.0970 - val_accuracy: 0.9618 - val_loss: 0.1344
# Epoch 10/20
# 299/300 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9763 - loss: 0.0827
# Epoch 10: val_accuracy did not improve from 0.96177
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9744 - loss: 0.0861 - val_accuracy: 0.9608 - val_loss: 0.1350
# Epoch 11/20
# 298/300 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9779 - loss: 0.0762
# Epoch 11: val_accuracy improved from 0.96177 to 0.96281, saving model to best_fcn_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 11: finished saving model to best_fcn_model.h5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9769 - loss: 0.0765 - val_accuracy: 0.9628 - val_loss: 0.1300
# Epoch 12/20
# 298/300 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9793 - loss: 0.0678
# Epoch 12: val_accuracy did not improve from 0.96281
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9794 - loss: 0.0682 - val_accuracy: 0.9616 - val_loss: 0.1290
# Epoch 13/20
# 294/300 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9820 - loss: 0.0588
# Epoch 13: val_accuracy improved from 0.96281 to 0.96427, saving model to best_fcn_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 13: finished saving model to best_fcn_model.h5
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9820 - loss: 0.0609 - val_accuracy: 0.9643 - val_loss: 0.1237
# Epoch 14/20
# 294/300 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9843 - loss: 0.0562
# Epoch 14: val_accuracy did not improve from 0.96427
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9842 - loss: 0.0545 - val_accuracy: 0.9635 - val_loss: 0.1285
# Epoch 15/20
# 298/300 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9865 - loss: 0.0494
# Epoch 15: val_accuracy did not improve from 0.96427
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9864 - loss: 0.0484 - val_accuracy: 0.9638 - val_loss: 0.1315
# Epoch 16/20
# 294/300 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9886 - loss: 0.0420
# Epoch 16: val_accuracy did not improve from 0.96427
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9887 - loss: 0.0417 - val_accuracy: 0.9628 - val_loss: 0.1338
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 13.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9657 - loss: 0.1171
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Loss: 0.11710352450609207
# Test Accuracy: 0.965666651725769
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9657 - loss: 0.1171
# Loaded Model Test Loss: 0.11710352450609207
# Loaded Model Test Accuracy: 0.965666651725769
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# [7 7 3 5 6 9 6 6 7 3]
# [7 7 3 5 6 9 6 6 7 2]
